# %%
import numpy as np
import matplotlib.pyplot as plt
from utils import plot_lines

# %%
A = np.array([
        [-1, 3],
        [3, 2]
    ], dtype=np.dtype(float))

b = np.array([7, 1], dtype=np.dtype(float))

print("Matrix A:")
print(A)
print("\nArray b:")
print(b)
# Out:
# Matrix A:
# [[-1.  3.]
#  [ 3.  2.]]
#
# Array b:
# [7. 1.]

# %%
print(f"Shape of A: {A.shape}")
print(f"Shape of b: {b.shape}")

# print(f"Shape of A: {np.shape(A)}")
# print(f"Shape of A: {np.shape(b)}")
# Out:
# Shape of A: (2, 2)
# Shape of b: (2,)

# %%
x = np.linalg.solve(A, b)

print(f"Solution: {x}")
# Out:
# Solution: [-1.  2.]

# %%
d = np.linalg.det(A)

print(f"Determinant of matrix A: {d:.2f}")
# Out:
# Determinant of matrix A: -11.00

# %%
A_system = np.hstack((A, b.reshape((2, 1))))

print(A_system)
# Out:
# [[-1.  3.  7.]
#  [ 3.  2.  1.]]

# %%
print(A_system[1])
# Out:
# [3. 2. 1.]

# %%
plot_lines(A_system)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 plot_lines(A_system)
#
# File c:\Users\shiv3\OneDrive\Desktop\Github\Practice_Python\Mathematics for Machine Learning and Data Science\utils.py:3, in plot_lines(A_system)
#       1 def plot_lines(A_system):
#       2     # Setup the x values for plotting
# ----> 3     x_vals = np.linspace(-10, 10, 100)
#       5     # Extract coefficients for row 1: a1*x1 + b1*x2 = c1 -> x2 = (c1 - a1*x1) / b1
#       6     row1 = A_system[0]
#
# NameError: name 'np' is not defined

# %%
A_2 = np.array([
        [-1, 3],
        [3, -9]
    ], dtype=np.dtype(float))

b_2 = np.array([7, 1], dtype=np.dtype(float))

d_2 = np.linalg.det(A_2)

print(f"Determinant of matrix A_2: {d_2:.2f}")
# Out:
# Determinant of matrix A_2: 0.00

# %%
A_2_system = np.hstack((A_2, b_2.reshape((2, 1))))
print(A_2_system)
# Out:
# [[-1.  3.  7.]
#  [ 3. -9.  1.]]

# %%
plot_lines(A_2_system)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 plot_lines(A_2_system)
#
# File c:\Users\shiv3\OneDrive\Desktop\Github\Practice_Python\Mathematics for Machine Learning and Data Science\utils.py:3, in plot_lines(A_system)
#       1 def plot_lines(A_system):
#       2     # Setup the x values for plotting
# ----> 3     x_vals = np.linspace(-10, 10, 100)
#       5     # Extract coefficients for row 1: a1*x1 + b1*x2 = c1 -> x2 = (c1 - a1*x1) / b1
#       6     row1 = A_system[0]
#
# NameError: name 'np' is not defined

# %%
b_3 = np.array([7, -21], dtype=np.dtype(float))

# %%
A_3_system = np.hstack((A_2, b_3.reshape((2, 1))))
print(A_3_system)
# Out:
# [[ -1.   3.   7.]
#  [  3.  -9. -21.]]

# %%
plot_lines(A_3_system)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 plot_lines(A_3_system)
#
# File c:\Users\shiv3\OneDrive\Desktop\Github\Practice_Python\Mathematics for Machine Learning and Data Science\utils.py:3, in plot_lines(A_system)
#       1 def plot_lines(A_system):
#       2     # Setup the x values for plotting
# ----> 3     x_vals = np.linspace(-10, 10, 100)
#       5     # Extract coefficients for row 1: a1*x1 + b1*x2 = c1 -> x2 = (c1 - a1*x1) / b1
#       6     row1 = A_system[0]
#
# NameError: name 'np' is not defined
