# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('E_Webdata.csv')

# %%
df
# Out:
#              # ----------------------------------------  \
# 0     Session primary channel group (Default channel...
# 1                                                Direct
# 2                                        Organic Social
# 3                                                Direct
# 4                                        Organic Social
# ...                                                 ...
# 3178                                         Unassigned
# 3179                                         Unassigned
# 3180                                         Unassigned
# 3181                                         Unassigned
# 3182                                         Unassigned
#
#                     Unnamed: 1 Unnamed: 2 Unnamed: 3        Unnamed: 4  \
# 0     Date + hour (YYYYMMDDHH)      Users   Sessions  Engaged sessions
# 1                   2024041623        237        300               144
# 2                   2024041719        208        267               132
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3183 entries, 0 to 3182
# Data columns (total 10 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   # ----------------------------------------  3183 non-null   str
#  1   Unnamed: 1                                  3183 non-null   str
#  2   Unnamed: 2                                  3183 non-null   str
#  3   Unnamed: 3                                  3183 non-null   str
#  4   Unnamed: 4                                  3183 non-null   str
#  5   Unnamed: 5                                  3183 non-null   str
#  6   Unnamed: 6                                  3183 non-null   str
#  7   Unnamed: 7                                  3183 non-null   str
#  8   Unnamed: 8                                  3183 non-null   str
#  9   Unnamed: 9                                  3183 non-null   str
# dtypes: str(10)
# ...

# %%
df.columns = df.iloc[0]
# Make index 0 row as header

# %%
df.columns
# Out:
# Index(['Session primary channel group (Default channel group)',
#        'Date + hour (YYYYMMDDHH)', 'Users', 'Sessions', 'Engaged sessions',
#        'Average engagement time per session', 'Engaged sessions per user',
#        'Events per session', 'Engagement rate', 'Event count'],
#       dtype='str', name=0)

# %%
df = df.drop(index = 0).reset_index(drop = True)
# Drop row on index 0

df.columns = ['channel group','Datehour', 'Users', 'Sessions', 'Engaged sessions','Average engagement time per session', 'Engaged sessions per user','Events per session', 'Engagement rate', 'Event count']
# Correct the name of columns in header

# %%
df['Datehour'] = pd.to_datetime(df['Datehour'], format = '%Y%m%d%H', errors = 'coerce')
df.head()
# Out:
#     channel group            Datehour Users Sessions Engaged sessions  \
# 0          Direct 2024-04-16 23:00:00   237      300              144
# 1  Organic Social 2024-04-17 19:00:00   208      267              132
# 2          Direct 2024-04-17 23:00:00   188      233              115
# 3  Organic Social 2024-04-17 18:00:00   187      256              125
# 4  Organic Social 2024-04-17 20:00:00   175      221              112
#
#   Average engagement time per session Engaged sessions per user  \
# 0                  47.526666666666700        0.6075949367088610
# 1                   32.09737827715360        0.6346153846153850
# 2                   39.93991416309010        0.6117021276595740
# 3                         32.16015625        0.6684491978609630
# 4                  46.918552036199100                      0.64
#
#   Events per session      Engagement rate Event count
# 0  4.673333333333330                 0.48        1402
# ...

# %%
#Here we wish to convert the rest of the columns except 'channel group','Datehour' to numeric

numeric_col = df.columns.drop(['channel group','Datehour'])
df[numeric_col] = df[numeric_col].apply(pd.to_numeric, errors = 'coerce')
df['Hour'] = df['Datehour'].dt.hour

# %%
df.head()
# Out:
#     channel group            Datehour  Users  Sessions  Engaged sessions  \
# 0          Direct 2024-04-16 23:00:00    237       300               144
# 1  Organic Social 2024-04-17 19:00:00    208       267               132
# 2          Direct 2024-04-17 23:00:00    188       233               115
# 3  Organic Social 2024-04-17 18:00:00    187       256               125
# 4  Organic Social 2024-04-17 20:00:00    175       221               112
#
#    Average engagement time per session  Engaged sessions per user  \
# 0                            47.526667                   0.607595
# 1                            32.097378                   0.634615
# 2                            39.939914                   0.611702
# 3                            32.160156                   0.668449
# 4                            46.918552                   0.640000
#
#    Events per session  Engagement rate  Event count  Hour
# 0            4.673333         0.480000         1402    23
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3182 entries, 0 to 3181
# Data columns (total 11 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   channel group                        3182 non-null   str
#  1   Datehour                             3182 non-null   datetime64[us]
#  2   Users                                3182 non-null   int64
#  3   Sessions                             3182 non-null   int64
#  4   Engaged sessions                     3182 non-null   int64
#  5   Average engagement time per session  3182 non-null   float64
#  6   Engaged sessions per user            3182 non-null   float64
#  7   Events per session                   3182 non-null   float64
#  8   Engagement rate                      3182 non-null   float64
#  9   Event count                          3182 non-null   int64
#  10  Hour                                 3182 non-null   int32
# ...

# %%
df.describe()
# Out:
#                          Datehour        Users     Sessions  Engaged sessions  \
# count                        3182  3182.000000  3182.000000       3182.000000
# mean   2024-04-20 01:17:07.278441    41.935889    51.192646         28.325581
# min           2024-04-06 00:00:00     0.000000     1.000000          0.000000
# 25%           2024-04-13 02:15:00    20.000000    24.000000         13.000000
# 50%           2024-04-20 02:00:00    42.000000    51.000000         27.000000
# 75%           2024-04-26 22:00:00    60.000000    71.000000         41.000000
# max           2024-05-03 23:00:00   237.000000   300.000000        144.000000
# std                           NaN    29.582258    36.919962         20.650569
#
#        Average engagement time per session  Engaged sessions per user  \
# count                          3182.000000                3182.000000
# mean                             66.644581                   0.606450
# ...

# %% [markdown]
# ##### Session and user over time

# %%
sns.set(style='whitegrid')

# %%
plt.figure(figsize = (10,5))
df.groupby('Datehour')[['Sessions','Users']].sum().plot(ax = plt.gca())

plt.title('Sessions and users over time')
plt.xlabel('Datehour')
plt.ylabel('Count of users')

plt.show()

# %% [markdown]
# ##### Total users by channel

# %%
df.head()
# Out:
#     channel group            Datehour  Users  Sessions  Engaged sessions  \
# 0          Direct 2024-04-16 23:00:00    237       300               144
# 1  Organic Social 2024-04-17 19:00:00    208       267               132
# 2          Direct 2024-04-17 23:00:00    188       233               115
# 3  Organic Social 2024-04-17 18:00:00    187       256               125
# 4  Organic Social 2024-04-17 20:00:00    175       221               112
#
#    Average engagement time per session  Engaged sessions per user  \
# 0                            47.526667                   0.607595
# 1                            32.097378                   0.634615
# 2                            39.939914                   0.611702
# 3                            32.160156                   0.668449
# 4                            46.918552                   0.640000
#
#    Events per session  Engagement rate  Event count  Hour
# 0            4.673333         0.480000         1402    23
# ...

# %%
plt.figure(figsize = (10,6))

sns.barplot(x = 'channel group', y = 'Users', data = df, color = 'orange')

plt.title('Number of users by channel')
plt.xlabel('channels')
plt.ylabel('numbers of users')
plt.xticks(rotation = 30)
plt.show()

# %% [markdown]
# ##### Avg. engegment time by channel

# %%
df.head()
# Out:
#     channel group            Datehour  Users  Sessions  Engaged sessions  \
# 0          Direct 2024-04-16 23:00:00    237       300               144
# 1  Organic Social 2024-04-17 19:00:00    208       267               132
# 2          Direct 2024-04-17 23:00:00    188       233               115
# 3  Organic Social 2024-04-17 18:00:00    187       256               125
# 4  Organic Social 2024-04-17 20:00:00    175       221               112
#
#    Average engagement time per session  Engaged sessions per user  \
# 0                            47.526667                   0.607595
# 1                            32.097378                   0.634615
# 2                            39.939914                   0.611702
# 3                            32.160156                   0.668449
# 4                            46.918552                   0.640000
#
#    Events per session  Engagement rate  Event count  Hour
# 0            4.673333         0.480000         1402    23
# ...

# %%
plt.figure(figsize = (12,6))

sns.barplot(data = df, x = 'channel group', y = 'Average engagement time per session', estimator = np.mean, color = 'orange' )

plt.title('Average engegment time by channel')
plt.xticks(rotation = 30)
plt.show()

# %% [markdown]
# ##### Engegment rate distribution by channel

# %%
df.head()
# Out:
#     channel group            Datehour  Users  Sessions  Engaged sessions  \
# 0          Direct 2024-04-16 23:00:00    237       300               144
# 1  Organic Social 2024-04-17 19:00:00    208       267               132
# 2          Direct 2024-04-17 23:00:00    188       233               115
# 3  Organic Social 2024-04-17 18:00:00    187       256               125
# 4  Organic Social 2024-04-17 20:00:00    175       221               112
#
#    Average engagement time per session  Engaged sessions per user  \
# 0                            47.526667                   0.607595
# 1                            32.097378                   0.634615
# 2                            39.939914                   0.611702
# 3                            32.160156                   0.668449
# 4                            46.918552                   0.640000
#
#    Events per session  Engagement rate  Event count  Hour
# 0            4.673333         0.480000         1402    23
# ...

# %%
plt.figure(figsize = (12,6))

sns.barplot(data = df, x = 'channel group', y = 'Engagement rate', color = 'orange')

plt.title('Average rate by channel')
plt.xticks(rotation = 30)
plt.show()
