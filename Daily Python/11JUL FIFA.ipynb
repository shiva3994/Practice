# %%
import pandas as pd
import numpy as nb
import matplotlib as plt

# %%
df = pd.read_csv("players_15.csv")

# %%
df.head(2)
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   27  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   29  1985-02-05
#
#    height_cm  weight_kg nationality     club_name  ...   lwb   ldm   cdm  \
# 0        169         67   Argentina  FC Barcelona  ...  62+3  62+3  62+3
# 1        185         80    Portugal   Real Madrid  ...  63+3  63+3  63+3
#
#     rdm   rwb    lb   lcb    cb   rcb    rb
# 0  62+3  62+3  54+3  45+3  45+3  45+3  54+3
# 1  63+3  63+3  57+3  52+3  52+3  52+3  57+3
#
# [2 rows x 106 columns]

# %%
df.tail(2)
# Out:
#        sofifa_id                                         player_url  \
# 16153     222947  https://sofifa.com/player/222947/tom-davies/15...
# 16154     201197  https://sofifa.com/player/201197/paul-tisdale/...
#
#        short_name     long_name  age         dob  height_cm  weight_kg  \
# 16153   T. Davies    Tom Davies   22  1992-04-18        180         70
# 16154  P. Tisdale  Paul Tisdale   41  1973-01-14        175         72
#
#       nationality       club_name  ...   lwb   ldm   cdm   rdm   rwb    lb  \
# 16153     England  Fleetwood Town  ...  37+0  36+0  36+0  36+0  37+0  39+0
# 16154       Malta     Exeter City  ...  36+0  37+0  37+0  37+0  36+0  34+0
#
#         lcb    cb   rcb    rb
# 16153  40+0  40+0  40+0  39+0
# 16154  33+0  33+0  33+0  34+0
#
# [2 rows x 106 columns]

# %%
df.shape
# Out:
# (16155, 106)

# %%
df.columns
# Out:
# Index(['sofifa_id', 'player_url', 'short_name', 'long_name', 'age', 'dob',
#        'height_cm', 'weight_kg', 'nationality', 'club_name',
#        ...
#        'lwb', 'ldm', 'cdm', 'rdm', 'rwb', 'lb', 'lcb', 'cb', 'rcb', 'rb'],
#       dtype='object', length=106)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16155 entries, 0 to 16154
# Columns: 106 entries, sofifa_id to rb
# dtypes: float64(18), int64(44), object(44)
# memory usage: 13.1+ MB

# %%
df.describe()
# Out:
#            sofifa_id           age     height_cm     weight_kg   league_rank  \
# count   16155.000000  16155.000000  16155.000000  16155.000000  15916.000000
# mean   189284.184525     24.776230    181.083627     75.474342      1.378424
# std     39749.261554      4.625321      6.618974      6.891796      0.736796
# min         2.000000     16.000000    155.000000     50.000000      1.000000
# 25%    178042.500000     21.000000    176.000000     70.000000      1.000000
# 50%    200841.000000     24.000000    181.000000     75.000000      1.000000
# 75%    214346.000000     28.000000    186.000000     80.000000      2.000000
# max    225562.000000     44.000000    204.000000    110.000000      4.000000
#
#             overall     potential     value_eur       wage_eur  \
# count  16155.000000  16155.000000  1.615500e+04   16155.000000
# mean      63.830393     68.350108  1.060882e+06   13056.453110
# std        7.169896      6.580610  2.819128e+06   23488.182571
# ...

# %%
df.dtypes
# Out:
# sofifa_id      int64
# player_url    object
# short_name    object
# long_name     object
# age            int64
#                ...
# lb            object
# lcb           object
# cb            object
# rcb           object
# rb            object
# Length: 106, dtype: object

# %%
df["height_cm"]
# Out:
# 0        169
# 1        185
# 2        180
# 3        195
# 4        193
#         ...
# 16150    187
# 16151    178
# 16152    190
# 16153    180
# 16154    175
# Name: height_cm, Length: 16155, dtype: int64

# %%
mean = df["height_cm"].mean()

# %%
#Standard deviation
sd = df["height_cm"].std()

# %%
# How many people are above 183
# Z = (x - Mew)/sigma
# (185 - mean) / sd

tallerthan185 = (185 - mean) / sd

# %%
tallerthan185
# Out:
# np.float64(0.5916887429753471)

# %%
shorterthan173 = (175 - mean) / sd

# %%
shorterthan173
# Out:
# np.float64(-0.9191193372482548)

# %%
# Weight probability of pickiung someone whose weight is between 90 and 100

# %%
# Calculate mean
meanw = df["weight_kg"].mean()

# %%
# Calculate mean
sdw = df["weight_kg"].std()

# %%
# Calculate z for 90
above90 = (90 - meanw) / sdw

# %%
above90
# Out:
# np.float64(2.107673821629863)

# %%
# Calculate z for 90
below100 = (100 - meanw) / sdw

# %%
below100
# Out:
# np.float64(3.5586744347853987)

# %%
#table vale for .99981 table value for .98214

# %%
# Probability for pickiung someone whose weight is between 90 and 100
probw = (.99981 - .98214) * 100

# %%
probw
# Out:
# 1.7669999999999964
