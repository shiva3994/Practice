# %% [markdown]
# # What is a distributionm
#
# A sample of data will form a distribution, and by far the most well-known distribution is the Gaussian distribution, often called the Normal distribution.
#
# ---
#
# ### Normal Distribution
# Normal distribution, also known as the Gaussian distribution, is a probability distribution that is symmetric about the mean, showing that data near the mean are more frequent in occurrence than data far from the mean.
#
# In graphical form, the normal distribution appears as a "bell curve".
#
# ![Normal Distribution](https://www.investopedia.com/thmb/d4jrAW0IPGrI133cZd6IoSh-Kbk=/660x0/filters:no_upscale():max_bytes(150000):strip_icc():format(webp)/The-Normal-Distribution1-51cb75a3e0a34eb6bbff7e966557757e.jpg)
#
#
# ![normal_distribution](https://www.gstatic.com/education/formulas2/472522532/en/normal_distribution.svg)

# %% [markdown]
# ### Let's look at some data
# I am going to take the data from the game **Fifa 15**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np


df = pd.read_csv('dataset/players_15.csv')

# %%
df.head()
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2       9014  https://sofifa.com/player/9014/arjen-robben/15...
# 3      41236  https://sofifa.com/player/41236/zlatan-ibrahim...
# 4     167495  https://sofifa.com/player/167495/manuel-neuer/...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   27  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   29  1985-02-05
# 2          A. Robben                         Arjen Robben   30  1984-01-23
# 3     Z. Ibrahimović                   Zlatan Ibrahimović   32  1981-10-03
# 4           M. Neuer                         Manuel Neuer   28  1986-03-27
#
#    height_cm  weight_kg  nationality            club_name  ...   lwb   ldm  \
# ...

# %%
df['height_cm']
# Out:
# 0        169
# 1        185
# 2        180
# 3        195
# 4        193
#         ...
# 16150    187
# 16151    178
# 16152    190
# 16153    180
# 16154    175
# Name: height_cm, Length: 16155, dtype: int64

# %%
df['height_cm'].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['height_cm'].mean()
# Out:
# np.float64(181.08362735995047)

# %%
df['x_xbar'] = df['height_cm'] - df['height_cm'].mean()

# %%
df['x_xbar_squared'] = df['x_xbar'] ** 2

# %%
df['x_xbar_squared']
# Out:
# 0        146.014050
# 1         15.337975
# 2          1.174248
# 3        193.665427
# 4        141.999937
#             ...
# 16150     35.003465
# 16151      9.508758
# 16152     79.501701
# 16153      1.174248
# 16154     37.010522
# Name: x_xbar_squared, Length: 16155, dtype: float64

# %%
df['x_xbar_squared'].sum()
# Out:
# np.float64(707720.019436707)

# %%
len(df['x_xbar_squared'])
# Out:
# 16155

# %%
df['x_xbar_squared'].sum() / len(df['x_xbar_squared'])
# Out:
# np.float64(43.80811014773798)

# %%
import math 
math.sqrt(df['x_xbar_squared'].sum() / len(df['x_xbar_squared']))
# Out:
# 6.618769534266772

# %%
df['height_cm'].std()
# Out:
# np.float64(6.6189743958213425)

# %%
df['height_cm'].mean()
# Out:
# np.float64(181.08362735995047)

# %%
df['height_cm'].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# What is the probability of someone scoring more than 193

# %% [markdown]
# ### We calculate something called z values

# %%
df['height_cm'].mean()
# Out:
# np.float64(181.08362735995047)

# %%
df['height_cm'].std()
# Out:
# np.float64(6.6189743958213425)

# %%
### Calculating the Z value

(174 - df['height_cm'].mean())/ df['height_cm'].std()
# Out:
# np.float64(-1.0702001452706131)

# %% [markdown]
# ### Practice Question
# Take the height columns.
#
# - What ithe probability of someone being taller than 185
# - What ithe probability of someone being shorter than 175
# - What ithe probability of someone being between 183 - 193˛

# %%
### Calculating the Z value

(183 - df['height_cm'].mean())/ df['height_cm'].std()
# Out:
# np.float64(0.2895271269306262)

# %%
### Calculating the Z value

(193 - df['height_cm'].mean())/ df['height_cm'].std()
# Out:
# np.float64(1.8003352071542253)

# %% [markdown]
# ### Hints to do this
#
# - Calculate the Z-value for the value of your "x"
# - Take this z-value to the z-table and get yourself the number which represents "area under the curve"
# - Plot your z-value on your normal curve and figure out if you are interested in the right side of the curve or the left side.
# - Base your answer based on this observation

# %%
df['height_cm'].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
### Calculating the Z value

(185 - df['height_cm'].mean())/ df['height_cm'].std()
# Out:
# np.float64(0.591688742975346)

# %%
72.24

# %% [markdown]
# ### Let's look at the weight columns

# %%
df['weight_kg']
# Out:
# 0        67
# 1        80
# 2        80
# 3        95
# 4        92
#          ..
# 16150    81
# 16151    57
# 16152    76
# 16153    70
# 16154    72
# Name: weight_kg, Length: 16155, dtype: int64

# %%
df['weight_kg'].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['weight_kg'].hist(bins=20)
# Out:
# <Axes: >

# %% [markdown]
# ### Let's close this out with the last question for the day
#
# - What is the probability of picking someone whose weight is between 90 and 100

# %%
### Calculating the Z value

(90 - df['weight_kg'].mean())/ df['weight_kg'].std()
# Out:
# np.float64(2.1076738216298896)

# %%
(100 - df['weight_kg'].mean())/ df['weight_kg'].std()
# Out:
# np.float64(3.5586744347854435)

# %% [markdown]
# # Break time.
# We meet back at 9:25
#
# ![](https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQwWhxidl1fiX4KHE7hXVza4v4Y7c4F47eXhKwfwRdbMg&s=10)
